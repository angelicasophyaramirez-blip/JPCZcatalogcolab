# %% [markdown]
# # 04 NDJF Catalog
#
# This notebook builds the first-pass November-December-January-February ERA5 JPCZ catalog using the stabilized module workflow. It reuses completed December checkpoints when available, applies month-specific divergence thresholds, and writes the final master catalog to Google Drive.

# %%
# Python excludes the final endpoint: this covers calendar years 2000–2025.
# Use the current ARCO `valid_time_stop` printed below before adding later months.
CATALOG_YEARS = tuple(range(2000, 2026))
CATALOG_MONTHS = (11, 12, 1, 2)
WRITE_FINAL_OUTPUTS = True

print("CATALOG_YEARS:", CATALOG_YEARS)
print("CATALOG_MONTHS:", CATALOG_MONTHS)
print("WRITE_FINAL_OUTPUTS:", WRITE_FINAL_OUTPUTS)
# Out:
# CATALOG_YEARS: (2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025)
# CATALOG_MONTHS: (11, 12, 1, 2)
# WRITE_FINAL_OUTPUTS: True

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/angelicasophyaramirez-blip/JPCZcatalogcolab.git"
# This notebook requires the same branch as its helper modules.
BRANCH = "codex/notebook16-pcolormesh"
REPO_DIR = "/content/JPCZcatalog"
FORCE_REFRESH_REPO = True
PERSIST_OUTPUTS_TO_DRIVE = True
DRIVE_OUTPUT_DIR = "/content/drive/MyDrive/JPCZcatalog_outputs"

if PERSIST_OUTPUTS_TO_DRIVE:
    from google.colab import drive

    drive.mount("/content/drive")
    os.makedirs(DRIVE_OUTPUT_DIR, exist_ok=True)
    print("Persistent output dir:", DRIVE_OUTPUT_DIR)

os.chdir("/content")

if FORCE_REFRESH_REPO and os.path.exists(REPO_DIR):
    shutil.rmtree(REPO_DIR)
    print("Removed existing repo clone:", REPO_DIR)

if not os.path.exists(REPO_DIR):
    proc = subprocess.run(
        ["git", "clone", "--depth", "1", "--branch", BRANCH, REPO_URL, REPO_DIR],
        text=True,
        capture_output=True,
    )
    print(proc.stdout)
    print(proc.stderr)
    if proc.returncode != 0:
        raise RuntimeError(f"git clone failed:\n{proc.stderr}")

    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "-r", f"{REPO_DIR}/requirements-colab.txt"],
        check=True,
    )
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "-e", REPO_DIR],
        check=True,
    )
else:
    print("Using existing repo clone:", REPO_DIR)

os.chdir(REPO_DIR)
src_dir = os.path.join(REPO_DIR, "src")
if src_dir not in sys.path:
    sys.path.insert(0, src_dir)

print("Working directory:", os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Persistent output dir: /content/drive/MyDrive/JPCZcatalog_outputs
# Removed existing repo clone: /content/JPCZcatalog
#
# Cloning into '/content/JPCZcatalog'...
#
# Working directory: /content/JPCZcatalog

# %%
from pathlib import Path
import pandas as pd
import xarray as xr

from jpcz_catalog.detect import count_events_from_threshold, threshold_from_std

# Keep this aligned with the control cell at the top of the notebook.
CATALOG_YEARS = tuple(range(2000, 2026))
CATALOG_MONTHS = (11, 12, 1, 2)

drive_dir = Path("/content/drive/MyDrive/JPCZcatalog_outputs")
ndjf_checkpoint_dir = drive_dir / "ndjf_monthly"
december_checkpoint_dir = drive_dir / "december_yearly"

if not ndjf_checkpoint_dir.exists():
    raise FileNotFoundError(f"Missing NDJF checkpoint directory: {ndjf_checkpoint_dir}")

monthly_records = []

for year in CATALOG_YEARS:
    for month in CATALOG_MONTHS:
        reusable_december_path = december_checkpoint_dir / f"december_{year}_D.nc"
        checkpoint_path = (
            reusable_december_path
            if month == 12 and reusable_december_path.exists()
            else ndjf_checkpoint_dir / f"{year}_{month:02d}_D.nc"
        )

        if not checkpoint_path.exists():
            # This is an optional recovery/inspection cell. During an extension
            # run, later years have not been calculated yet; do not stop here.
            print(f"Checkpoint not built yet; skipping in recovery cell: {checkpoint_path}")
            continue

        D_valid = xr.open_dataarray(checkpoint_path).load()
        monthly_records.append({
            "year": year,
            "month": month,
            "D": D_valid,
        })

        print(
            f"Loaded {year}-{month:02d}: "
            f"valid_D={D_valid.sizes['time']}, "
            f"peak_D={float(D_valid.min().values):.3e} s^-1"
        )

month_threshold_rows = []
threshold_by_month = {}

for month in CATALOG_MONTHS:
    month_D = xr.concat(
        [record["D"] for record in monthly_records if record["month"] == month],
        dim="time",
    ).sortby("time")

    D_mean, D_std, D_threshold = threshold_from_std(month_D, n_std=2.0)
    threshold_by_month[month] = D_threshold
    month_threshold_rows.append({
        "month": month,
        "D_mean_s-1": D_mean,
        "D_std_s-1": D_std,
        "threshold_s-1": D_threshold,
        "threshold_1e5_s-1": D_threshold * 1e5,
    })

month_threshold_df = pd.DataFrame(month_threshold_rows).sort_values("month")

event_frames = []
for record in monthly_records:
    events_month = count_events_from_threshold(record["D"], threshold_by_month[record["month"]]).copy()
    if events_month.empty:
        continue

    events_month["year"] = record["year"]
    events_month["month"] = record["month"]
    events_month["season_year"] = record["year"] if record["month"] in (1, 2) else record["year"] + 1
    events_month["detection_threshold_s-1"] = threshold_by_month[record["month"]]
    events_month["detection_threshold_1e5_s-1"] = threshold_by_month[record["month"]] * 1e5
    event_frames.append(events_month)

ndjf_events_df = pd.concat(event_frames, ignore_index=True).sort_values("event_peak").reset_index(drop=True)

print("Recovered NDJF events:", len(ndjf_events_df))
print(month_threshold_df)
# Out:
# Loaded 2000-11: valid_D=709, peak_D=-2.067e-05 s^-1
# Loaded 2000-12: valid_D=733, peak_D=-3.415e-05 s^-1
# Loaded 2000-01: valid_D=733, peak_D=-2.972e-05 s^-1
# Loaded 2000-02: valid_D=685, peak_D=-4.312e-05 s^-1
# Loaded 2001-11: valid_D=709, peak_D=-2.191e-05 s^-1
# Loaded 2001-12: valid_D=733, peak_D=-3.852e-05 s^-1
# Loaded 2001-01: valid_D=733, peak_D=-3.137e-05 s^-1
# Loaded 2001-02: valid_D=661, peak_D=-3.535e-05 s^-1
# Loaded 2002-11: valid_D=709, peak_D=-3.740e-05 s^-1
# Loaded 2002-12: valid_D=733, peak_D=-3.087e-05 s^-1
# Loaded 2002-01: valid_D=733, peak_D=-3.926e-05 s^-1
# Loaded 2002-02: valid_D=661, peak_D=-3.217e-05 s^-1
# Loaded 2003-11: valid_D=709, peak_D=-1.810e-05 s^-1
# Loaded 2003-12: valid_D=733, peak_D=-3.910e-05 s^-1
# Loaded 2003-01: valid_D=733, peak_D=-3.335e-05 s^-1
# Loaded 2003-02: valid_D=661, peak_D=-2.032e-05 s^-1
# Loaded 2004-11: valid_D=709, peak_D=-3.323e-05 s^-1
# Loaded 2004-12: valid_D=733, peak_D=-2.981e-05 s^-1
# Loaded 2004-01: valid_D=733, peak_D=-3.843e-05 s^-1
# Loaded 2004-02: valid_D=685, peak_D=-3.492e-05 s^-1
# Loaded 2005-11: valid_D=709, peak_D=-2.213e-05 s^-1
# Loaded 2005-12: valid_D=733, peak_D=-3.846e-05 s^-1
# Loaded 2005-01: valid_D=733, peak_D=-3.040e-05 s^-1
# Loaded 2005-02: valid_D=661, peak_D=-3.144e-05 s^-1
# Loaded 2006-11: valid_D=709, peak_D=-2.266e-05 s^-1
# Loaded 2006-12: valid_D=733, peak_D=-3.392e-05 s^-1
# Loaded 2006-01: valid_D=733, peak_D=-2.374e-05 s^-1
# Loaded 2006-02: valid_D=661, peak_D=-3.096e-05 s^-1
# Loaded 2007-11: valid_D=709, peak_D=-2.456e-05 s^-1
# Loaded 2007-12: valid_D=733, peak_D=-4.002e-05 s^-1
# Loaded 2007-01: valid_D=733, peak_D=-2.315e-05 s^-1
# Loaded 2007-02: valid_D=661, peak_D=-2.182e-05 s^-1
# Loaded 2008-11: valid_D=709, peak_D=-2.881e-05 s^-1
# Loaded 2008-12: valid_D=733, peak_D=-4.106e-05 s^-1
# Loaded 2008-01: valid_D=733, peak_D=-3.528e-05 s^-1
# Loaded 2008-02: valid_D=685, peak_D=-2.656e-05 s^-1
# Loaded 2009-11: valid_D=709, peak_D=-2.297e-05 s^-1
# Loaded 2009-12: valid_D=733, peak_D=-4.075e-05 s^-1
# Loaded 2009-01: valid_D=733, peak_D=-2.663e-05 s^-1
# Loaded 2009-02: valid_D=661, peak_D=-2.160e-05 s^-1
# Loaded 2010-11: valid_D=709, peak_D=-2.463e-05 s^-1
# Loaded 2010-12: valid_D=733, peak_D=-3.315e-05 s^-1
# Loaded 2010-01: valid_D=733, peak_D=-4.055e-05 s^-1
# Loaded 2010-02: valid_D=661, peak_D=-3.500e-05 s^-1
# Loaded 2011-11: valid_D=709, peak_D=-2.875e-05 s^-1
# Loaded 2011-12: valid_D=733, peak_D=-3.036e-05 s^-1
# Loaded 2011-01: valid_D=733, peak_D=-5.125e-05 s^-1
# Loaded 2011-02: valid_D=661, peak_D=-1.921e-05 s^-1
# Loaded 2012-11: valid_D=709, peak_D=-2.209e-05 s^-1
# Loaded 2012-12: valid_D=733, peak_D=-4.569e-05 s^-1
# Loaded 2012-01: valid_D=733, peak_D=-3.246e-05 s^-1
# Loaded 2012-02: valid_D=685, peak_D=-2.862e-05 s^-1
# Loaded 2013-11: valid_D=709, peak_D=-3.513e-05 s^-1
# Loaded 2013-12: valid_D=733, peak_D=-3.878e-05 s^-1
# Loaded 2013-01: valid_D=733, peak_D=-2.805e-05 s^-1
# Loaded 2013-02: valid_D=661, peak_D=-2.778e-05 s^-1
# Loaded 2014-11: valid_D=709, peak_D=-1.969e-05 s^-1
# Loaded 2014-12: valid_D=733, peak_D=-4.362e-05 s^-1
# Loaded 2014-01: valid_D=733, peak_D=-2.872e-05 s^-1
# Loaded 2014-02: valid_D=661, peak_D=-1.957e-05 s^-1
# Loaded 2015-11: valid_D=709, peak_D=-4.921e-05 s^-1
# Loaded 2015-12: valid_D=733, peak_D=-1.911e-05 s^-1
# Loaded 2015-01: valid_D=733, peak_D=-3.781e-05 s^-1
# Loaded 2015-02: valid_D=661, peak_D=-3.688e-05 s^-1
# Loaded 2016-11: valid_D=709, peak_D=-3.669e-05 s^-1
# Loaded 2016-12: valid_D=733, peak_D=-3.643e-05 s^-1
# Loaded 2016-01: valid_D=733, peak_D=-4.068e-05 s^-1
# Loaded 2016-02: valid_D=685, peak_D=-2.186e-05 s^-1
# Loaded 2017-11: valid_D=709, peak_D=-3.437e-05 s^-1
# Loaded 2017-12: valid_D=733, peak_D=-3.686e-05 s^-1
# Loaded 2017-01: valid_D=733, peak_D=-4.170e-05 s^-1
# Loaded 2017-02: valid_D=661, peak_D=-3.558e-05 s^-1
# Loaded 2018-11: valid_D=709, peak_D=-1.715e-05 s^-1
# Loaded 2018-12: valid_D=733, peak_D=-3.675e-05 s^-1
# Loaded 2018-01: valid_D=733, peak_D=-3.262e-05 s^-1
# Loaded 2018-02: valid_D=661, peak_D=-3.302e-05 s^-1
# Loaded 2019-11: valid_D=709, peak_D=-2.123e-05 s^-1
# Loaded 2019-12: valid_D=733, peak_D=-3.256e-05 s^-1
# Loaded 2019-01: valid_D=733, peak_D=-3.183e-05 s^-1
# Loaded 2019-02: valid_D=661, peak_D=-3.789e-05 s^-1
# Loaded 2020-11: valid_D=709, peak_D=-3.966e-05 s^-1
# Loaded 2020-12: valid_D=733, peak_D=-3.618e-05 s^-1
# Loaded 2020-01: valid_D=733, peak_D=-5.297e-05 s^-1
# Loaded 2020-02: valid_D=685, peak_D=-2.920e-05 s^-1
# Loaded 2021-11: valid_D=709, peak_D=-4.110e-05 s^-1
# Loaded 2021-12: valid_D=733, peak_D=-4.609e-05 s^-1
# Loaded 2021-01: valid_D=733, peak_D=-3.511e-05 s^-1
# Loaded 2021-02: valid_D=661, peak_D=-2.533e-05 s^-1
# Loaded 2022-11: valid_D=709, peak_D=-2.895e-05 s^-1
# Loaded 2022-12: valid_D=733, peak_D=-3.348e-05 s^-1
# Loaded 2022-01: valid_D=733, peak_D=-3.535e-05 s^-1
# Loaded 2022-02: valid_D=661, peak_D=-2.525e-05 s^-1
# Loaded 2023-11: valid_D=709, peak_D=-3.290e-05 s^-1
# Loaded 2023-12: valid_D=733, peak_D=-2.922e-05 s^-1
# Loaded 2023-01: valid_D=733, peak_D=-4.079e-05 s^-1
# Loaded 2023-02: valid_D=661, peak_D=-2.274e-05 s^-1
# Loaded 2024-11: valid_D=709, peak_D=-2.613e-05 s^-1
# Loaded 2024-12: valid_D=733, peak_D=-2.823e-05 s^-1
# Loaded 2024-01: valid_D=733, peak_D=-2.766e-05 s^-1
# Loaded 2024-02: valid_D=685, peak_D=-2.437e-05 s^-1
# Loaded 2025-11: valid_D=709, peak_D=-2.486e-05 s^-1
# Loaded 2025-12: valid_D=733, peak_D=-4.665e-05 s^-1
# Loaded 2025-01: valid_D=733, peak_D=-3.582e-05 s^-1
# Loaded 2025-02: valid_D=661, peak_D=-3.093e-05 s^-1
# Recovered NDJF events: 287
#    month  D_mean_s-1  D_std_s-1  threshold_s-1  threshold_1e5_s-1
# 2      1   -0.000004   0.000010      -0.000024          -2.438219
# 3      2   -0.000002   0.000009      -0.000020          -1.973395
# 0     11   -0.000002   0.000008      -0.000018          -1.826880
# 1     12   -0.000005   0.000010      -0.000026          -2.557050

# %%
from pathlib import Path
import shutil

local_dir = Path("outputs/verification")
local_dir.mkdir(parents=True, exist_ok=True)

ndjf_events_path = local_dir / "ndjf_events_first_pass.csv"
month_thresholds_path = local_dir / "ndjf_monthly_thresholds.csv"

ndjf_events_df.to_csv(ndjf_events_path, index=False)
month_threshold_df.to_csv(month_thresholds_path, index=False)

drive_dir = Path("/content/drive/MyDrive/JPCZcatalog_outputs")
for path in [ndjf_events_path, month_thresholds_path]:
    shutil.copy2(path, drive_dir / path.name)
    print(f"Copied {path} -> {drive_dir / path.name}")
# Out:
# Copied outputs/verification/ndjf_events_first_pass.csv -> /content/drive/MyDrive/JPCZcatalog_outputs/ndjf_events_first_pass.csv
# Copied outputs/verification/ndjf_monthly_thresholds.csv -> /content/drive/MyDrive/JPCZcatalog_outputs/ndjf_monthly_thresholds.csv

# %%
from pathlib import Path
import shutil

import pandas as pd
import xarray as xr

from jpcz_catalog.config import DECEMBER_BENCHMARK_YEARS, JPCZ_POLYGON_VERTICES
from jpcz_catalog.detect import (
    compute_polygon_mean_divergence_series,
    count_events_from_threshold,
    prepare_detection_geometry,
    threshold_from_std,
)
from jpcz_catalog.era5 import open_arco_era5, open_month
from jpcz_catalog.verification import write_text_summary

ds = open_arco_era5()
print("valid_time_start:", ds.attrs.get("valid_time_start"))
print("valid_time_stop:", ds.attrs.get("valid_time_stop"))

geometry_ds = open_month(ds, CATALOG_YEARS[0], 11)
geometry = prepare_detection_geometry(
    geometry_ds.longitude,
    geometry_ds.latitude,
    JPCZ_POLYGON_VERTICES,
)

ndjf_checkpoint_dir = Path(DRIVE_OUTPUT_DIR) / "ndjf_monthly" if PERSIST_OUTPUTS_TO_DRIVE else Path("outputs/verification/ndjf_monthly")
december_checkpoint_dir = Path(DRIVE_OUTPUT_DIR) / "december_yearly"
ndjf_checkpoint_dir.mkdir(parents=True, exist_ok=True)
print("NDJF checkpoint dir:", ndjf_checkpoint_dir)

total_hourly_points = 0
monthly_records = []

for year in CATALOG_YEARS:
    for month in CATALOG_MONTHS:
        reusable_december_path = december_checkpoint_dir / f"december_{year}_D.nc"
        checkpoint_path = reusable_december_path if month == 12 and reusable_december_path.exists() else ndjf_checkpoint_dir / f"{year}_{month:02d}_D.nc"

        if checkpoint_path.exists():
            D_valid = xr.open_dataarray(checkpoint_path).load()
            hourly_points = int(D_valid.sizes["time"] + 11)
            total_hourly_points += hourly_points
            monthly_records.append({
                "year": year,
                "month": month,
                "hourly_points": hourly_points,
                "D": D_valid,
            })
            print(
                f"{year}-{month:02d}: loaded checkpoint hourly={hourly_points}, "
                f"valid_D={D_valid.sizes['time']}, "
                f"peak_D={float(D_valid.min().values):.3e} s^-1"
            )
            continue

        print(f"{year}-{month:02d}: new checkpoint; loading hourly ERA5 winds from ARCO...")
        month_ds = open_month(ds, year, month)
        print(f"{year}-{month:02d}: subset selected; loading and calculating divergence...")
        hourly_month, D_month, _ = compute_polygon_mean_divergence_series(
            month_ds,
            geometry=geometry,
        )
        D_valid = D_month.dropna("time")
        D_valid.to_netcdf(checkpoint_path)

        total_hourly_points += int(hourly_month.sizes["time"])
        monthly_records.append({
            "year": year,
            "month": month,
            "hourly_points": int(hourly_month.sizes["time"]),
            "D": D_valid,
        })
        print(
            f"{year}-{month:02d}: hourly={hourly_month.sizes['time']}, "
            f"valid_D={D_valid.sizes['time']}, "
            f"peak_D={float(D_valid.min().values):.3e} s^-1"
        )

month_threshold_rows = []
threshold_by_month = {}

for month in CATALOG_MONTHS:
    month_D = xr.concat([record["D"] for record in monthly_records if record["month"] == month], dim="time").sortby("time")
    D_mean, D_std, D_threshold = threshold_from_std(month_D, n_std=2.0)
    threshold_by_month[month] = D_threshold
    month_threshold_rows.append({
        "month": month,
        "D_mean_s-1": D_mean,
        "D_std_s-1": D_std,
        "threshold_s-1": D_threshold,
        "threshold_1e5_s-1": D_threshold * 1e5,
    })

month_threshold_df = pd.DataFrame(month_threshold_rows).sort_values("month")

event_frames = []
for record in monthly_records:
    events_month = count_events_from_threshold(record["D"], threshold_by_month[record["month"]]).copy()
    if events_month.empty:
        continue

    events_month["year"] = record["year"]
    events_month["month"] = record["month"]
    events_month["season_year"] = record["year"] if record["month"] in (1, 2) else record["year"] + 1
    events_month["detection_threshold_s-1"] = threshold_by_month[record["month"]]
    events_month["detection_threshold_1e5_s-1"] = threshold_by_month[record["month"]] * 1e5
    event_frames.append(events_month)

if event_frames:
    ndjf_events_df = pd.concat(event_frames, ignore_index=True).sort_values("event_peak").reset_index(drop=True)
else:
    ndjf_events_df = pd.DataFrame()

if WRITE_FINAL_OUTPUTS:
    ndjf_events_path = Path("outputs/verification/ndjf_events_first_pass.csv")
    ndjf_events_df.to_csv(ndjf_events_path, index=False)
    month_thresholds_path = Path("outputs/verification/ndjf_monthly_thresholds.csv")
    month_threshold_df.to_csv(month_thresholds_path, index=False)

    if PERSIST_OUTPUTS_TO_DRIVE:
        for path in [ndjf_events_path, month_thresholds_path]:
            shutil.copy2(path, Path(DRIVE_OUTPUT_DIR) / path.name)
else:
    print("Checkpoint-only mode: skipping top-level NDJF first-pass outputs for this chunk run.")

print("Total hourly NDJF points:", total_hourly_points)
print("Total NDJF events:", len(ndjf_events_df))
print(month_threshold_df)
ndjf_events_df.head()
# Out:
# valid_time_start: 1940-01-01
# valid_time_stop: 2026-04-30
# NDJF checkpoint dir: /content/drive/MyDrive/JPCZcatalog_outputs/ndjf_monthly
# 2000-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.067e-05 s^-1
# 2000-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.415e-05 s^-1
# 2000-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-2.972e-05 s^-1
# 2000-02: loaded checkpoint hourly=696, valid_D=685, peak_D=-4.312e-05 s^-1
# 2001-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.191e-05 s^-1
# 2001-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.852e-05 s^-1
# 2001-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.137e-05 s^-1
# 2001-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-3.535e-05 s^-1
# 2002-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-3.740e-05 s^-1
# 2002-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.087e-05 s^-1
# 2002-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.926e-05 s^-1
# 2002-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-3.217e-05 s^-1
# 2003-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-1.810e-05 s^-1
# 2003-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.910e-05 s^-1
# 2003-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.335e-05 s^-1
# 2003-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-2.032e-05 s^-1
# 2004-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-3.323e-05 s^-1
# 2004-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-2.981e-05 s^-1
# 2004-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.843e-05 s^-1
# 2004-02: loaded checkpoint hourly=696, valid_D=685, peak_D=-3.492e-05 s^-1
# 2005-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.213e-05 s^-1
# 2005-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.846e-05 s^-1
# 2005-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.040e-05 s^-1
# 2005-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-3.144e-05 s^-1
# 2006-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.266e-05 s^-1
# 2006-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.392e-05 s^-1
# 2006-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-2.374e-05 s^-1
# 2006-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-3.096e-05 s^-1
# 2007-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.456e-05 s^-1
# 2007-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-4.002e-05 s^-1
# 2007-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-2.315e-05 s^-1
# 2007-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-2.182e-05 s^-1
# 2008-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.881e-05 s^-1
# 2008-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-4.106e-05 s^-1
# 2008-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.528e-05 s^-1
# 2008-02: loaded checkpoint hourly=696, valid_D=685, peak_D=-2.656e-05 s^-1
# 2009-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.297e-05 s^-1
# 2009-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-4.075e-05 s^-1
# 2009-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-2.663e-05 s^-1
# 2009-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-2.160e-05 s^-1
# 2010-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.463e-05 s^-1
# 2010-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.315e-05 s^-1
# 2010-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-4.055e-05 s^-1
# 2010-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-3.500e-05 s^-1
# 2011-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.875e-05 s^-1
# 2011-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.036e-05 s^-1
# 2011-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-5.125e-05 s^-1
# 2011-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-1.921e-05 s^-1
# 2012-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.209e-05 s^-1
# 2012-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-4.569e-05 s^-1
# 2012-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.246e-05 s^-1
# 2012-02: loaded checkpoint hourly=696, valid_D=685, peak_D=-2.862e-05 s^-1
# 2013-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-3.513e-05 s^-1
# 2013-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.878e-05 s^-1
# 2013-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-2.805e-05 s^-1
# 2013-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-2.778e-05 s^-1
# 2014-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-1.969e-05 s^-1
# 2014-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-4.362e-05 s^-1
# 2014-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-2.872e-05 s^-1
# 2014-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-1.957e-05 s^-1
# 2015-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-4.921e-05 s^-1
# 2015-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-1.911e-05 s^-1
# 2015-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.781e-05 s^-1
# 2015-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-3.688e-05 s^-1
# 2016-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-3.669e-05 s^-1
# 2016-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.643e-05 s^-1
# 2016-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-4.068e-05 s^-1
# 2016-02: loaded checkpoint hourly=696, valid_D=685, peak_D=-2.186e-05 s^-1
# 2017-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-3.437e-05 s^-1
# 2017-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.686e-05 s^-1
# 2017-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-4.170e-05 s^-1
# 2017-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-3.558e-05 s^-1
# 2018-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-1.715e-05 s^-1
# 2018-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.675e-05 s^-1
# 2018-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.262e-05 s^-1
# 2018-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-3.302e-05 s^-1
# 2019-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.123e-05 s^-1
# 2019-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.256e-05 s^-1
# 2019-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.183e-05 s^-1
# 2019-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-3.789e-05 s^-1
# 2020-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-3.966e-05 s^-1
# 2020-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.618e-05 s^-1
# 2020-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-5.297e-05 s^-1
# 2020-02: loaded checkpoint hourly=696, valid_D=685, peak_D=-2.920e-05 s^-1
# 2021-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-4.110e-05 s^-1
# 2021-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-4.609e-05 s^-1
# 2021-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.511e-05 s^-1
# 2021-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-2.533e-05 s^-1
# 2022-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.895e-05 s^-1
# 2022-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.348e-05 s^-1
# 2022-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.535e-05 s^-1
# 2022-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-2.525e-05 s^-1
# 2023-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-3.290e-05 s^-1
# 2023-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-2.922e-05 s^-1
# 2023-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-4.079e-05 s^-1
# 2023-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-2.274e-05 s^-1
# 2024-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.613e-05 s^-1
# 2024-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-2.823e-05 s^-1
# 2024-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-2.766e-05 s^-1
# 2024-02: loaded checkpoint hourly=696, valid_D=685, peak_D=-2.437e-05 s^-1
# 2025-11: loaded checkpoint hourly=720, valid_D=709, peak_D=-2.486e-05 s^-1
# 2025-12: loaded checkpoint hourly=744, valid_D=733, peak_D=-4.665e-05 s^-1
# 2025-01: loaded checkpoint hourly=744, valid_D=733, peak_D=-3.582e-05 s^-1
# 2025-02: loaded checkpoint hourly=672, valid_D=661, peak_D=-3.093e-05 s^-1
# Total hourly NDJF points: 75048
# Total NDJF events: 287
#    month  D_mean_s-1  D_std_s-1  threshold_s-1  threshold_1e5_s-1
# 2      1   -0.000004   0.000010      -0.000024          -2.438219
# 3      2   -0.000002   0.000009      -0.000020          -1.973395
# 0     11   -0.000002   0.000008      -0.000018          -1.826880
# 1     12   -0.000005   0.000010      -0.000026          -2.557050
#           event_start           event_end          event_peak  \
# 0 2000-01-13 08:00:00 2000-01-13 14:00:00 2000-01-13 11:00:00
# 1 2000-01-19 22:00:00 2000-01-20 08:00:00 2000-01-20 04:00:00
# 2 2000-02-07 13:00:00 2000-02-08 13:00:00 2000-02-08 00:00:00
# 3 2000-02-13 18:00:00 2000-02-14 03:00:00 2000-02-13 22:00:00
# 4 2000-02-14 13:00:00 2000-02-16 01:00:00 2000-02-14 22:00:00
#
#    event_peak_D_s-1  event_peak_D_1e5_s-1  duration_hours  year  month  \
# 0         -0.000030             -2.972377               7  2000      1
# 1         -0.000029             -2.927972              11  2000      1
# 2         -0.000043             -4.312036              25  2000      2
# 3         -0.000024             -2.398227              10  2000      2
# 4         -0.000036             -3.603144              37  2000      2
#
#    season_year  detection_threshold_s-1  detection_threshold_1e5_s-1
# 0         2000                -0.000024                    -2.438219
# 1         2000                -0.000024                    -2.438219
# 2         2000                -0.000020                    -1.973395
# 3         2000                -0.000020                    -1.973395
# 4         2000                -0.000020                    -1.973395

# %%
from pathlib import Path
import shutil

import numpy as np
import pandas as pd

from jpcz_catalog.classify import (
    annotate_events_with_environment,
    compute_month_climatological_slp_index,
)
from jpcz_catalog.verification import render_ndjf_catalog_summary, write_text_summary

if not WRITE_FINAL_OUTPUTS:
    raise RuntimeError("Set WRITE_FINAL_OUTPUTS = True before running the final NDJF classification cell.")

if "ndjf_events_df" not in globals():
    ndjf_events_df = pd.read_csv(
        Path("outputs/verification/ndjf_events_first_pass.csv"),
        parse_dates=["event_start", "event_end", "event_peak"],
    )

environment_checkpoint_path = Path(DRIVE_OUTPUT_DIR) / 'ndjf_event_environment_checkpoint.csv'
ndjf_catalog = annotate_events_with_environment(
    ds,
    ndjf_events_df,
    checkpoint_path=environment_checkpoint_path,
    checkpoint_every=1,
    progress_label='NDJF event environment',
)

slp_mean_by_month = {}
slp_std_by_month = {}
for month in CATALOG_MONTHS:
    _, mean_value, std_value = compute_month_climatological_slp_index(ds, month, years=CATALOG_YEARS)
    slp_mean_by_month[month] = mean_value
    slp_std_by_month[month] = std_value

ndjf_catalog["slp_climatology_mean_hpa"] = ndjf_catalog["month"].map(slp_mean_by_month)
ndjf_catalog["slp_climatology_std_hpa"] = ndjf_catalog["month"].map(slp_std_by_month)
ndjf_catalog["monsoon_type"] = np.where(
    ndjf_catalog["slp_diff_hpa"] > ndjf_catalog["slp_climatology_mean_hpa"],
    "Type 1 strong-monsoon",
    "Type 2 weak-monsoon",
)

type1_mask = ndjf_catalog["monsoon_type"] == "Type 1 strong-monsoon"
if type1_mask.sum() == 0:
    raise ValueError("No Type 1 strong-monsoon events were detected in the NDJF catalog.")

zeta_split_ndjf = (
    ndjf_catalog.loc[type1_mask, "zeta_box_mean_s-1"].mean()
    + ndjf_catalog.loc[type1_mask, "zeta_box_mean_s-1"].std()
)

ndjf_catalog["shinoda_class"] = "Type 2 weak-monsoon"
ndjf_catalog.loc[
    type1_mask & (ndjf_catalog["zeta_box_mean_s-1"] > zeta_split_ndjf),
    "shinoda_class",
] = "Type 1B higher-vorticity"
ndjf_catalog.loc[
    type1_mask & (ndjf_catalog["zeta_box_mean_s-1"] <= zeta_split_ndjf),
    "shinoda_class",
] = "Type 1A lower-vorticity"

slp_thresholds_df = pd.DataFrame(
    {
        "month": list(CATALOG_MONTHS),
        "slp_climatology_mean_hpa": [slp_mean_by_month[m] for m in CATALOG_MONTHS],
        "slp_climatology_std_hpa": [slp_std_by_month[m] for m in CATALOG_MONTHS],
    }
).sort_values("month")

slp_thresholds_path = Path("outputs/verification/ndjf_monsoon_thresholds.csv")
slp_thresholds_df.to_csv(slp_thresholds_path, index=False)

final_catalog_path = Path("outputs/verification/jpcz_catalog_ndjf.csv")
ndjf_catalog.to_csv(final_catalog_path, index=False)

summary_text = render_ndjf_catalog_summary(
    total_events=len(ndjf_catalog),
    month_threshold_df=month_threshold_df,
    catalog_df=ndjf_catalog,
)
summary_path = write_text_summary("outputs/verification/jpcz_catalog_ndjf_summary.md", summary_text)

if PERSIST_OUTPUTS_TO_DRIVE:
    for path in [slp_thresholds_path, final_catalog_path, summary_path]:
        shutil.copy2(path, Path(DRIVE_OUTPUT_DIR) / path.name)

print(summary_text)
print("NDJF zeta split:", zeta_split_ndjf, "s^-1")
ndjf_catalog.head()
# Out:
# NDJF event environment: checkpointed 1/287 events (1 total saved).
# NDJF event environment: checkpointed 2/287 events (2 total saved).
# NDJF event environment: checkpointed 3/287 events (3 total saved).
# NDJF event environment: checkpointed 4/287 events (4 total saved).
# NDJF event environment: checkpointed 5/287 events (5 total saved).
# NDJF event environment: checkpointed 6/287 events (6 total saved).
# NDJF event environment: checkpointed 7/287 events (7 total saved).
# NDJF event environment: checkpointed 8/287 events (8 total saved).
# NDJF event environment: checkpointed 9/287 events (9 total saved).
# NDJF event environment: checkpointed 10/287 events (10 total saved).
# NDJF event environment: checkpointed 11/287 events (11 total saved).
# NDJF event environment: checkpointed 12/287 events (12 total saved).
# NDJF event environment: checkpointed 13/287 events (13 total saved).
# NDJF event environment: checkpointed 14/287 events (14 total saved).
# NDJF event environment: checkpointed 15/287 events (15 total saved).
# NDJF event environment: checkpointed 16/287 events (16 total saved).
# NDJF event environment: checkpointed 17/287 events (17 total saved).
# NDJF event environment: checkpointed 18/287 events (18 total saved).
# NDJF event environment: checkpointed 19/287 events (19 total saved).
# NDJF event environment: checkpointed 20/287 events (20 total saved).
# NDJF event environment: checkpointed 21/287 events (21 total saved).
# NDJF event environment: checkpointed 22/287 events (22 total saved).
# NDJF event environment: checkpointed 23/287 events (23 total saved).
# NDJF event environment: checkpointed 24/287 events (24 total saved).
# NDJF event environment: checkpointed 25/287 events (25 total saved).
# NDJF event environment: checkpointed 26/287 events (26 total saved).
# NDJF event environment: checkpointed 27/287 events (27 total saved).
# NDJF event environment: checkpointed 28/287 events (28 total saved).
# NDJF event environment: checkpointed 29/287 events (29 total saved).
# NDJF event environment: checkpointed 30/287 events (30 total saved).
# NDJF event environment: checkpointed 31/287 events (31 total saved).
# NDJF event environment: checkpointed 32/287 events (32 total saved).
# NDJF event environment: checkpointed 33/287 events (33 total saved).
# NDJF event environment: checkpointed 34/287 events (34 total saved).
# NDJF event environment: checkpointed 35/287 events (35 total saved).
# NDJF event environment: checkpointed 36/287 events (36 total saved).
# NDJF event environment: checkpointed 37/287 events (37 total saved).
# NDJF event environment: checkpointed 38/287 events (38 total saved).
# NDJF event environment: checkpointed 39/287 events (39 total saved).
# NDJF event environment: checkpointed 40/287 events (40 total saved).
# NDJF event environment: checkpointed 41/287 events (41 total saved).
# NDJF event environment: checkpointed 42/287 events (42 total saved).
# NDJF event environment: checkpointed 43/287 events (43 total saved).
# NDJF event environment: checkpointed 44/287 events (44 total saved).
# NDJF event environment: checkpointed 45/287 events (45 total saved).
# NDJF event environment: checkpointed 46/287 events (46 total saved).
# NDJF event environment: checkpointed 47/287 events (47 total saved).
# NDJF event environment: checkpointed 48/287 events (48 total saved).
# NDJF event environment: checkpointed 49/287 events (49 total saved).
# NDJF event environment: checkpointed 50/287 events (50 total saved).
# NDJF event environment: checkpointed 51/287 events (51 total saved).
# NDJF event environment: checkpointed 52/287 events (52 total saved).
# NDJF event environment: checkpointed 53/287 events (53 total saved).
# NDJF event environment: checkpointed 54/287 events (54 total saved).
# NDJF event environment: checkpointed 55/287 events (55 total saved).
# NDJF event environment: checkpointed 56/287 events (56 total saved).
# NDJF event environment: checkpointed 57/287 events (57 total saved).
# NDJF event environment: checkpointed 58/287 events (58 total saved).
# NDJF event environment: checkpointed 59/287 events (59 total saved).
# NDJF event environment: checkpointed 60/287 events (60 total saved).
# NDJF event environment: checkpointed 61/287 events (61 total saved).
# NDJF event environment: checkpointed 62/287 events (62 total saved).
# NDJF event environment: checkpointed 63/287 events (63 total saved).
# NDJF event environment: checkpointed 64/287 events (64 total saved).
# NDJF event environment: checkpointed 65/287 events (65 total saved).
# NDJF event environment: checkpointed 66/287 events (66 total saved).
# NDJF event environment: checkpointed 67/287 events (67 total saved).
# NDJF event environment: checkpointed 68/287 events (68 total saved).
# NDJF event environment: checkpointed 69/287 events (69 total saved).
# NDJF event environment: checkpointed 70/287 events (70 total saved).
# NDJF event environment: checkpointed 71/287 events (71 total saved).
# NDJF event environment: checkpointed 72/287 events (72 total saved).
# NDJF event environment: checkpointed 73/287 events (73 total saved).
# NDJF event environment: checkpointed 74/287 events (74 total saved).
# NDJF event environment: checkpointed 75/287 events (75 total saved).
# NDJF event environment: checkpointed 76/287 events (76 total saved).
# NDJF event environment: checkpointed 77/287 events (77 total saved).
# NDJF event environment: checkpointed 78/287 events (78 total saved).
# NDJF event environment: checkpointed 79/287 events (79 total saved).
# NDJF event environment: checkpointed 80/287 events (80 total saved).
# NDJF event environment: checkpointed 81/287 events (81 total saved).
# NDJF event environment: checkpointed 82/287 events (82 total saved).
# NDJF event environment: checkpointed 83/287 events (83 total saved).
# NDJF event environment: checkpointed 84/287 events (84 total saved).
# NDJF event environment: checkpointed 85/287 events (85 total saved).
# NDJF event environment: checkpointed 86/287 events (86 total saved).
# NDJF event environment: checkpointed 87/287 events (87 total saved).
# NDJF event environment: checkpointed 88/287 events (88 total saved).
# NDJF event environment: checkpointed 89/287 events (89 total saved).
# NDJF event environment: checkpointed 90/287 events (90 total saved).
# NDJF event environment: checkpointed 91/287 events (91 total saved).
# NDJF event environment: checkpointed 92/287 events (92 total saved).
# NDJF event environment: checkpointed 93/287 events (93 total saved).
# NDJF event environment: checkpointed 94/287 events (94 total saved).
# NDJF event environment: checkpointed 95/287 events (95 total saved).
# NDJF event environment: checkpointed 96/287 events (96 total saved).
# NDJF event environment: checkpointed 97/287 events (97 total saved).
# NDJF event environment: checkpointed 98/287 events (98 total saved).
# NDJF event environment: checkpointed 99/287 events (99 total saved).
# NDJF event environment: checkpointed 100/287 events (100 total saved).
# NDJF event environment: checkpointed 101/287 events (101 total saved).
# NDJF event environment: checkpointed 102/287 events (102 total saved).
# NDJF event environment: checkpointed 103/287 events (103 total saved).
# NDJF event environment: checkpointed 104/287 events (104 total saved).
# NDJF event environment: checkpointed 105/287 events (105 total saved).
# NDJF event environment: checkpointed 106/287 events (106 total saved).
# NDJF event environment: checkpointed 107/287 events (107 total saved).
# NDJF event environment: checkpointed 108/287 events (108 total saved).
# NDJF event environment: checkpointed 109/287 events (109 total saved).
# NDJF event environment: checkpointed 110/287 events (110 total saved).
# NDJF event environment: checkpointed 111/287 events (111 total saved).
# NDJF event environment: checkpointed 112/287 events (112 total saved).
# NDJF event environment: checkpointed 113/287 events (113 total saved).
# NDJF event environment: checkpointed 114/287 events (114 total saved).
# NDJF event environment: checkpointed 115/287 events (115 total saved).
# NDJF event environment: checkpointed 116/287 events (116 total saved).
# NDJF event environment: checkpointed 117/287 events (117 total saved).
# NDJF event environment: checkpointed 118/287 events (118 total saved).
# NDJF event environment: checkpointed 119/287 events (119 total saved).
# NDJF event environment: checkpointed 120/287 events (120 total saved).
# NDJF event environment: checkpointed 121/287 events (121 total saved).
# NDJF event environment: checkpointed 122/287 events (122 total saved).
# NDJF event environment: checkpointed 123/287 events (123 total saved).
# NDJF event environment: checkpointed 124/287 events (124 total saved).
# NDJF event environment: checkpointed 125/287 events (125 total saved).
# NDJF event environment: checkpointed 126/287 events (126 total saved).
# NDJF event environment: checkpointed 127/287 events (127 total saved).
# NDJF event environment: checkpointed 128/287 events (128 total saved).
# NDJF event environment: checkpointed 129/287 events (129 total saved).
# NDJF event environment: checkpointed 130/287 events (130 total saved).
# NDJF event environment: checkpointed 131/287 events (131 total saved).
# NDJF event environment: checkpointed 132/287 events (132 total saved).
# NDJF event environment: checkpointed 133/287 events (133 total saved).
# NDJF event environment: checkpointed 134/287 events (134 total saved).
# NDJF event environment: checkpointed 135/287 events (135 total saved).
# NDJF event environment: checkpointed 136/287 events (136 total saved).
# NDJF event environment: checkpointed 137/287 events (137 total saved).
# NDJF event environment: checkpointed 138/287 events (138 total saved).
# NDJF event environment: checkpointed 139/287 events (139 total saved).
# NDJF event environment: checkpointed 140/287 events (140 total saved).
# NDJF event environment: checkpointed 141/287 events (141 total saved).
# NDJF event environment: checkpointed 142/287 events (142 total saved).
# NDJF event environment: checkpointed 143/287 events (143 total saved).
# NDJF event environment: checkpointed 144/287 events (144 total saved).
# NDJF event environment: checkpointed 145/287 events (145 total saved).
# NDJF event environment: checkpointed 146/287 events (146 total saved).
# NDJF event environment: checkpointed 147/287 events (147 total saved).
# NDJF event environment: checkpointed 148/287 events (148 total saved).
# NDJF event environment: checkpointed 149/287 events (149 total saved).
# NDJF event environment: checkpointed 150/287 events (150 total saved).
# NDJF event environment: checkpointed 151/287 events (151 total saved).
# NDJF event environment: checkpointed 152/287 events (152 total saved).
# NDJF event environment: checkpointed 153/287 events (153 total saved).
# NDJF event environment: checkpointed 154/287 events (154 total saved).
# NDJF event environment: checkpointed 155/287 events (155 total saved).
# NDJF event environment: checkpointed 156/287 events (156 total saved).
# NDJF event environment: checkpointed 157/287 events (157 total saved).
# NDJF event environment: checkpointed 158/287 events (158 total saved).
# NDJF event environment: checkpointed 159/287 events (159 total saved).
# NDJF event environment: checkpointed 160/287 events (160 total saved).
# NDJF event environment: checkpointed 161/287 events (161 total saved).
# NDJF event environment: checkpointed 162/287 events (162 total saved).
# NDJF event environment: checkpointed 163/287 events (163 total saved).
# NDJF event environment: checkpointed 164/287 events (164 total saved).
# NDJF event environment: checkpointed 165/287 events (165 total saved).
# NDJF event environment: checkpointed 166/287 events (166 total saved).
# NDJF event environment: checkpointed 167/287 events (167 total saved).
# NDJF event environment: checkpointed 168/287 events (168 total saved).
# NDJF event environment: checkpointed 169/287 events (169 total saved).
# NDJF event environment: checkpointed 170/287 events (170 total saved).
# NDJF event environment: checkpointed 171/287 events (171 total saved).
# NDJF event environment: checkpointed 172/287 events (172 total saved).
# NDJF event environment: checkpointed 173/287 events (173 total saved).
# NDJF event environment: checkpointed 174/287 events (174 total saved).
# NDJF event environment: checkpointed 175/287 events (175 total saved).
# NDJF event environment: checkpointed 176/287 events (176 total saved).
# NDJF event environment: checkpointed 177/287 events (177 total saved).
# NDJF event environment: checkpointed 178/287 events (178 total saved).
# NDJF event environment: checkpointed 179/287 events (179 total saved).
# NDJF event environment: checkpointed 180/287 events (180 total saved).
# NDJF event environment: checkpointed 181/287 events (181 total saved).
# NDJF event environment: checkpointed 182/287 events (182 total saved).
# NDJF event environment: checkpointed 183/287 events (183 total saved).
# NDJF event environment: checkpointed 184/287 events (184 total saved).
# NDJF event environment: checkpointed 185/287 events (185 total saved).
# NDJF event environment: checkpointed 186/287 events (186 total saved).
# NDJF event environment: checkpointed 187/287 events (187 total saved).
# NDJF event environment: checkpointed 188/287 events (188 total saved).
# NDJF event environment: checkpointed 189/287 events (189 total saved).
# NDJF event environment: checkpointed 190/287 events (190 total saved).
# NDJF event environment: checkpointed 191/287 events (191 total saved).
# NDJF event environment: checkpointed 192/287 events (192 total saved).
# NDJF event environment: checkpointed 193/287 events (193 total saved).
# NDJF event environment: checkpointed 194/287 events (194 total saved).
# NDJF event environment: checkpointed 195/287 events (195 total saved).
# NDJF event environment: checkpointed 196/287 events (196 total saved).
# NDJF event environment: checkpointed 197/287 events (197 total saved).
# NDJF event environment: checkpointed 198/287 events (198 total saved).
# NDJF event environment: checkpointed 199/287 events (199 total saved).
# NDJF event environment: checkpointed 200/287 events (200 total saved).
# NDJF event environment: checkpointed 201/287 events (201 total saved).
# NDJF event environment: checkpointed 202/287 events (202 total saved).
# NDJF event environment: checkpointed 203/287 events (203 total saved).
# NDJF event environment: checkpointed 204/287 events (204 total saved).
# NDJF event environment: checkpointed 205/287 events (205 total saved).
# NDJF event environment: checkpointed 206/287 events (206 total saved).
# NDJF event environment: checkpointed 207/287 events (207 total saved).
# NDJF event environment: checkpointed 208/287 events (208 total saved).
# NDJF event environment: checkpointed 209/287 events (209 total saved).
# NDJF event environment: checkpointed 210/287 events (210 total saved).
# NDJF event environment: checkpointed 211/287 events (211 total saved).
# NDJF event environment: checkpointed 212/287 events (212 total saved).
# NDJF event environment: checkpointed 213/287 events (213 total saved).
# NDJF event environment: checkpointed 214/287 events (214 total saved).
# NDJF event environment: checkpointed 215/287 events (215 total saved).
# NDJF event environment: checkpointed 216/287 events (216 total saved).
# NDJF event environment: checkpointed 217/287 events (217 total saved).
# NDJF event environment: checkpointed 218/287 events (218 total saved).
# NDJF event environment: checkpointed 219/287 events (219 total saved).
# NDJF event environment: checkpointed 220/287 events (220 total saved).
# NDJF event environment: checkpointed 221/287 events (221 total saved).
# NDJF event environment: checkpointed 222/287 events (222 total saved).
# NDJF event environment: checkpointed 223/287 events (223 total saved).
# NDJF event environment: checkpointed 224/287 events (224 total saved).
# NDJF event environment: checkpointed 225/287 events (225 total saved).
# NDJF event environment: checkpointed 226/287 events (226 total saved).
# NDJF event environment: checkpointed 227/287 events (227 total saved).
# NDJF event environment: checkpointed 228/287 events (228 total saved).
# NDJF event environment: checkpointed 229/287 events (229 total saved).
# NDJF event environment: checkpointed 230/287 events (230 total saved).
# NDJF event environment: checkpointed 231/287 events (231 total saved).
# NDJF event environment: checkpointed 232/287 events (232 total saved).
# NDJF event environment: checkpointed 233/287 events (233 total saved).
# NDJF event environment: checkpointed 234/287 events (234 total saved).
# NDJF event environment: checkpointed 235/287 events (235 total saved).
# NDJF event environment: checkpointed 236/287 events (236 total saved).
# NDJF event environment: checkpointed 237/287 events (237 total saved).
# NDJF event environment: checkpointed 238/287 events (238 total saved).
# NDJF event environment: checkpointed 239/287 events (239 total saved).
# NDJF event environment: checkpointed 240/287 events (240 total saved).
# NDJF event environment: checkpointed 241/287 events (241 total saved).
# NDJF event environment: checkpointed 242/287 events (242 total saved).
# NDJF event environment: checkpointed 243/287 events (243 total saved).
# NDJF event environment: checkpointed 244/287 events (244 total saved).
# NDJF event environment: checkpointed 245/287 events (245 total saved).
# NDJF event environment: checkpointed 246/287 events (246 total saved).
# NDJF event environment: checkpointed 247/287 events (247 total saved).
# NDJF event environment: checkpointed 248/287 events (248 total saved).
# NDJF event environment: checkpointed 249/287 events (249 total saved).
# NDJF event environment: checkpointed 250/287 events (250 total saved).
# NDJF event environment: checkpointed 251/287 events (251 total saved).
# NDJF event environment: checkpointed 252/287 events (252 total saved).
# NDJF event environment: checkpointed 253/287 events (253 total saved).
# NDJF event environment: checkpointed 254/287 events (254 total saved).
# NDJF event environment: checkpointed 255/287 events (255 total saved).
# NDJF event environment: checkpointed 256/287 events (256 total saved).
# NDJF event environment: checkpointed 257/287 events (257 total saved).
# NDJF event environment: checkpointed 258/287 events (258 total saved).
# NDJF event environment: checkpointed 259/287 events (259 total saved).
# NDJF event environment: checkpointed 260/287 events (260 total saved).
# NDJF event environment: checkpointed 261/287 events (261 total saved).
# NDJF event environment: checkpointed 262/287 events (262 total saved).
# NDJF event environment: checkpointed 263/287 events (263 total saved).
# NDJF event environment: checkpointed 264/287 events (264 total saved).
# NDJF event environment: checkpointed 265/287 events (265 total saved).
# NDJF event environment: checkpointed 266/287 events (266 total saved).
# NDJF event environment: checkpointed 267/287 events (267 total saved).
# NDJF event environment: checkpointed 268/287 events (268 total saved).
# NDJF event environment: checkpointed 269/287 events (269 total saved).
# NDJF event environment: checkpointed 270/287 events (270 total saved).
# NDJF event environment: checkpointed 271/287 events (271 total saved).
# NDJF event environment: checkpointed 272/287 events (272 total saved).
# NDJF event environment: checkpointed 273/287 events (273 total saved).
# NDJF event environment: checkpointed 274/287 events (274 total saved).
# NDJF event environment: checkpointed 275/287 events (275 total saved).
# NDJF event environment: checkpointed 276/287 events (276 total saved).
# NDJF event environment: checkpointed 277/287 events (277 total saved).
# NDJF event environment: checkpointed 278/287 events (278 total saved).
# NDJF event environment: checkpointed 279/287 events (279 total saved).
# NDJF event environment: checkpointed 280/287 events (280 total saved).
# NDJF event environment: checkpointed 281/287 events (281 total saved).
# NDJF event environment: checkpointed 282/287 events (282 total saved).
# NDJF event environment: checkpointed 283/287 events (283 total saved).
# NDJF event environment: checkpointed 284/287 events (284 total saved).
# NDJF event environment: checkpointed 285/287 events (285 total saved).
# NDJF event environment: checkpointed 286/287 events (286 total saved).
# NDJF event environment: checkpointed 287/287 events (287 total saved).
